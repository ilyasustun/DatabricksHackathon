# %% [markdown]
# ## Getting started with geospatial data in Python
# ### Prepared for WiDS Brownbag; August 5, 2020
# #### by Grace Kim

# %%
# Import modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from scipy import spatial
from netCDF4 import Dataset 
import datetime as dt
import geopandas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### This notebook compares data from the following sources:
# #### 1. [Chesapeake Monitoring Cooperative](https://cmc.vims.edu/#/home)
# The Chesapeake Monitoring Cooperative (CMC) is a group of leading organizations that provide technical, programmatic, and outreach support in order to integrate volunteer-based and non-traditional water quality and benthic macroinvertebrate monitoring data monitoring data into the Chesapeake Bay Program partnership.
# #### 2. [North American Regional Reanalysis](https://psl.noaa.gov/data/gridded/data.narr.html)
# A long-term, consistent, high-resolution climate dataset for the North American domain. Data used in our analysis are 3-hourly average air temperature, accumulated precipitation and wind speed.

# %%
### Data load for Databricks; replace with your own import command if using locally 
# File location and type
file_location = "/FileStore/alldata_master.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>Time</th><th>StationName</th><th>StationCode</th><th>Latitude</th><th>Longitude</th><th>GroupCode</th><th>SampleId</th><th>SampleDepth</th><th>airtemp</th><th>alkalinity</th><th>nh4</th><th>chla</th><th>conductivity</th><th>do_sat</th><th>do</th><th>entero</th><th>no3</th><th>no2</th><th>po4</th><th>ph</th><th>salinity</th><th>depth</th><th>tds</th><th>tn</th><th>tp</th><th>tss</th><th>watertemp</th><th>ntu</th><th>RainfallWithin24Hours</th><th>RainfallWithin48Hours</th><th>Rainfall</th><th>StreamFlow</th><th>TidalStage</th><th>WaterColorDescription</th><th>WaterColor</th><th>WaterSurfaces</th><th>WeatherConditionsToday</th><th>WeatherConditionsYesterday</th><th>WindSpeed</th><th>airtemp_narr</th><th>precip3_narr</th><th>precip24_narr</th><th>precip48_narr</th><th>windspeed_narr</th><th>HUC12</th></tr></thead><tbody><tr><td>2015-04-21 00:00:00</td><td>09:00:00</td><td>8-PLT-36-LACA</td><td>LACA.8-PLT-36-LACA</td><td>38.143611</td><td>-77.855555</td><td>LACA</td><td>1.0</td><td>0.3</td><td>17.0</td><td>nan</td><td>nan</td><td>8.52</td><td>nan</td><td>nan</td><td>9.33</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>7.29</td><td>nan</td><td>1.5</td><td>nan</td><td>0.65</td><td>0.06</td><td>nan</td><td>nan</td><td>19.12</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>14.97052</td><td>0.0</td><td>4.003388</td><td>4.235404</td><td>5.208091</td><td>20801060503</td></tr><tr><td>2014-10-07 00:00:00</td><td>10:00:00</td><td>EX-1</td><td>LACA.EX-1</td><td>38.11488</td><td>-78.01012</td><td>LACA</td><td>1.0</td><td>0.3</td><td>nan</td><td>nan</td><td>nan</td><td>18.6</td><td>0.048</td><td>nan</td><td>6.77</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>6.35</td><td>nan</td><td>nan</td><td>nan</td><td>0.6</td><td>0.03</td><td>nan</td><td>nan</td><td>nan</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>None</td><td>14.34552</td><td>0.0</td><td>2.7768254</td><td>3.344779</td><td>5.82062</td><td>20801060402</td></tr><tr><td>2019-03-24 00:00:00</td><td>15:20:00</td><td>BRCR1</td><td>NWA.BRCR1</td><td>38.5645</td><td>-75.6723</td><td>NWA</td><td>1.0</td><td>0.5</td><td>nan</td><td>nan</td><td>nan</td><td>13.9</td><td>nan</td><td>119.2</td><td>11.5</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>0.1</td><td>1.3</td><td>nan</td><td>6.21</td><td>0.05</td><td>nan</td><td>nan</td><td>11.1</td><td>None</td><td>None</td><td>None</td><td>None</td><td>Low</td><td>None</td><td>None</td><td>Ripple</td><td>Sunny</td><td>None</td><td>None</td><td>19.64972</td><td>0.0</td><td>1.519013</td><td>2.7265177</td><td>6.236149</td><td>20801090205</td></tr><tr><td>2017-04-09 00:00:00</td><td>17:40:00</td><td>COBR1</td><td>NWA.COBR1</td><td>38.6422</td><td>-75.6068</td><td>NWA</td><td>1.0</td><td>0.5</td><td>nan</td><td>nan</td><td>nan</td><td>16.21</td><td>nan</td><td>105.0</td><td>10.5</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>0.1</td><td>1.1</td><td>nan</td><td>4.59</td><td>0.05</td><td>nan</td><td>nan</td><td>15.9</td><td>None</td><td>None</td><td>None</td><td>None</td><td>High</td><td>None</td><td>None</td><td>Ripple</td><td>Sunny</td><td>None</td><td>None</td><td>13.587219</td><td>0.0</td><td>15.3237</td><td>12.210892</td><td>13.09209</td><td>20801090404</td></tr><tr><td>2019-06-30 00:00:00</td><td>17:35:00</td><td>DEHE3</td><td>NWA.DEHE3</td><td>38.6647</td><td>-75.5639</td><td>NWA</td><td>1.0</td><td>0.5</td><td>nan</td><td>nan</td><td>nan</td><td>2.08</td><td>nan</td><td>92.2</td><td>7.3</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>nan</td><td>0.1</td><td>0.7</td><td>nan</td><td>4.228</td><td>0.035</td><td>nan</td><td>nan</td><td>27.2</td><td>None</td><td>None</td><td>N ...

# %%
alldatadf = df.toPandas()
alldatadf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>StationName</th>
#       <th>StationCode</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>GroupCode</th>
#       <th>SampleId</th>
#       <th>SampleDepth</th>
#       <th>airtemp</th>
#       <th>alkalinity</th>
#       <th>nh4</th>
#       <th>chla</th>
#       <th>conductivity</th>
#       <th>do_sat</th>
#       <th>do</th>
#       <th>entero</th>
#       <th>no3</th>
#       <th>no2</th>
#       <th>po4</th>
#       <th>ph</th>
#       <th>salinity</th>
#       <th>depth</th>
#       <th>tds</th>
#       <th>tn</th>
#       <th>tp</th>
#       <th>tss</th>
#       <th>watertemp</th>
#       <th>ntu</th>
#       <th>RainfallWithin24Hours</th>
#       <th>RainfallWithin48Hours</th>
#       <th>Rainfall</th>
#       <th>StreamFlow</th>
#       <th>TidalStage</th>
#       <th>WaterColorDescription</th>
#       <th>WaterColor</th>
#       <th>WaterSurfaces</th>
#       <th>WeatherConditionsToday</th>
#       <th>WeatherConditionsYesterday</th>
#       <th>WindSpeed</th>
#       <th>airtemp_narr</th>
#       <th>precip3_narr</th>
#       <th>precip24_narr</th>
#       <th>precip48_narr</th>
#       <th>windspeed_narr</th>
#       <th>HUC12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-04-21 00:00:00</td>
#       <td>09:00:00</td>
#       <td>8-PLT-36-LACA</td>
#       <td>LACA.8-PLT-36-LACA</td>
#       <td>38.143611</td>
#       <td>-77.855555</td>
#       <td>LACA</td>
#       <td>1.0</td>
#       <td>0.3</td>
#       <td>17.0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>8.52</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>9.33</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>7.29</td>
#       <td>nan</td>
#       <td>1.5</td>
#       <td>nan</td>
#       <td>0.650</td>
#       <td>0.06</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>19.12</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>14.97052</td>
#       <td>0.0</td>
#       <td>4.003388</td>
#       <td>4.235404</td>
#       <td>5.208091</td>
#       <td>20801060503</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2014-10-07 00:00:00</td>
#       <td>10:00:00</td>
#       <td>EX-1</td>
#       <td>LACA.EX-1</td>
#       <td>38.114880</td>
#       <td>-78.010120</td>
#       <td>LACA</td>
#       <td>1.0</td>
#       <td>0.3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>18.6</td>
#       <td>0.048</td>
#       <td>nan</td>
#       <td>6.77</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>6.35</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.600</td>
#       <td>0.03</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>14.34552</td>
#       <td>0.0</td>
#       <td>2.7768254</td>
#       <td>3.344779</td>
#       <td>5.82062</td>
#       <td>20801060402</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2019-03-24 00:00:00</td>
#       <td>15:20:00</td>
#       <td>BRCR1</td>
#       <td>NWA.BRCR1</td>
#       <td>38.564500</td>
#       <td>-75.672300</td>
#       <td>NWA</td>
#       <td>1.0</td>
#       <td>0.5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>13.9</td>
#       <td>nan</td>
#       <td>119.2</td>
#       <td>11.5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.1</td>
#       <td>1.3</td>
#       <td>nan</td>
#       <td>6.210</td>
#       <td>0.05</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>11.1</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>Low</td>
#       <td>None</td>
#       <td>None</td>
#       <td>Ripple</td>
#       <td>Sunny</td>
#       <td>None</td>
#       <td>None</td>
#       <td>19.64972</td>
#       <td>0.0</td>
#       <td>1.519013</td>
#       <td>2.7265177</td>
#       <td>6.236149</td>
#       <td>20801090205</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-04-09 00:00:00</td>
#       <td>17:40:00</td>
#       <td>COBR1</td>
#       <td>NWA.COBR1</td>
#       <td>38.642200</td>
#       <td>-75.606800</td>
#       <td>NWA</td>
#       <td>1.0</td>
#       <td>0.5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>16.21</td>
#       <td>nan</td>
#       <td>105.0</td>
#       <td>10.5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.1</td>
#       <td>1.1</td>
#       <td>nan</td>
#       <td>4.590</td>
#       <td>0.05</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>15.9</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>High</td>
#       <td>None</td>
#       <td>None</td>
#       <td>Ripple</td>
#       <td>Sunny</td>
#       <td>None</td>
#       <td>None</td>
#       <td>13.587219</td>
#       <td>0.0</td>
#       <td>15.3237</td>
#       <td>12.210892</td>
#       <td>13.09209</td>
#       <td>20801090404</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2019-06-30 00:00:00</td>
#       <td>17:35:00</td>
#       <td>DEHE3</td>
#       <td>NWA.DEHE3</td>
#       <td>38.664700</td>
#       <td>-75.563900</td>
#       <td>NWA</td>
#       <td>1.0</td>
#       <td>0.5</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>2.08</td>
#       <td>nan</td>
#       <td>92.2</td>
#       <td>7.3</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.1</td>
#       <td>0.7</td>
#       <td>nan</td>
#       <td>4.228</td>
#       <td>0.035</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>27.2</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>High</td>
#       <td>None</td>
#       <td>None</td>
#       <td>Ripple</td>
#       <td>Sunny</td>
#       <td>None</td>
#       <td>None</td>
#       <td>10.71579</td>
#       <td>0.04910195</td>
#       <td>0.0050688675</td>
#       <td>1.5758352</td>
#       <td>2.195765</td>
#       <td>20801090404</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 1. Let's see when & where there are measurements of air temperature from the CMC sampling data

# %%
atdf=alldatadf.iloc[np.where(alldatadf.airtemp!="nan")][['Date','Time','Latitude','Longitude','airtemp']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
atdf.sort_values(by='Date').head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>airtemp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2045</th>
#       <td>2013-04-16 00:00:00</td>
#       <td>09:25:00</td>
#       <td>38.053611</td>
#       <td>-77.765555</td>
#       <td>15.1</td>
#     </tr>
#     <tr>
#       <th>1852</th>
#       <td>2013-04-16 00:00:00</td>
#       <td>09:56:00</td>
#       <td>38.053611</td>
#       <td>-77.841389</td>
#       <td>20.0</td>
#     </tr>
#     <tr>
#       <th>2308</th>
#       <td>2013-04-16 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.025278</td>
#       <td>-77.806944</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>1846</th>
#       <td>2013-04-16 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.143611</td>
#       <td>-77.855555</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>2032</th>
#       <td>2013-04-16 00:00:00</td>
#       <td>10:00:00</td>
#       <td>37.984722</td>
#       <td>-77.766944</td>
#       <td>17.5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
atdf.sort_values(by='Date').tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>airtemp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>873</th>
#       <td>2019-10-08 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.141667</td>
#       <td>-77.929722</td>
#       <td>14.5</td>
#     </tr>
#     <tr>
#       <th>2073</th>
#       <td>2019-10-08 00:00:00</td>
#       <td>10:20:00</td>
#       <td>38.143611</td>
#       <td>-77.855555</td>
#       <td>15.0</td>
#     </tr>
#     <tr>
#       <th>1938</th>
#       <td>2019-10-08 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.087083</td>
#       <td>-77.783861</td>
#       <td>22.5</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>2019-10-08 00:00:00</td>
#       <td>09:40:00</td>
#       <td>38.162780</td>
#       <td>-77.906940</td>
#       <td>15.5</td>
#     </tr>
#     <tr>
#       <th>1273</th>
#       <td>2019-10-08 00:00:00</td>
#       <td>09:05:00</td>
#       <td>38.025278</td>
#       <td>-77.806944</td>
#       <td>13.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
at_datetime=pd.to_datetime(atdf['Date'].astype(str) + ' ' + atdf['Time']).reset_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#data ranges
start_year=min(at_datetime).year
end_year=max(at_datetime).year
latrange=([min(alldatadf.Latitude), max(alldatadf.Latitude)])
lonrange=([min(alldatadf.Longitude), max(alldatadf.Longitude)])

print("year range:", start_year,"to",end_year)
print("lat range:", latrange)
print("lon range:", lonrange)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">year range: 2013 to 2019
# lat range: [37.02447, 42.37778]
# lon range: [-79.89764, -75.40639]
# </div>

# %% [markdown]
# ### Plot sampling locations

# %%
# make a geo data frame including the points of all the station locations
gdf=geopandas.GeoDataFrame(atdf,
                           geometry=geopandas.points_from_xy(
                             atdf.Longitude.astype(float),atdf.Latitude.astype(float)))
tn_gdf=geopandas.GeoDataFrame(alldatadf,
                           geometry=geopandas.points_from_xy(
                             alldatadf.Longitude.astype(float),alldatadf.Latitude.astype(float)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>airtemp</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-04-21 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.143611</td>
#       <td>-77.855555</td>
#       <td>17.0</td>
#       <td>POINT (-77.85555 38.14361)</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2019-09-25 00:00:00</td>
#       <td>13:57:00</td>
#       <td>39.459333</td>
#       <td>-75.880056</td>
#       <td>26.5</td>
#       <td>POINT (-75.88006 39.45933)</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2018-06-05 00:00:00</td>
#       <td>09:00:00</td>
#       <td>38.025278</td>
#       <td>-77.806944</td>
#       <td>25.2</td>
#       <td>POINT (-77.80694 38.02528)</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>2014-04-16 00:00:00</td>
#       <td>10:25:00</td>
#       <td>37.984722</td>
#       <td>-77.766944</td>
#       <td>5.5</td>
#       <td>POINT (-77.76694 37.98472)</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>2019-06-04 00:00:00</td>
#       <td>10:40:00</td>
#       <td>38.143611</td>
#       <td>-77.855555</td>
#       <td>22.5</td>
#       <td>POINT (-77.85555 38.14361)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
gdf.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: Date         226
# Time         226
# Latitude     226
# Longitude    226
# airtemp      226
# geometry     226
# dtype: int64</div>

# %%
# import a map of US states
fid=urllib.request.urlretrieve("https://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_040_00_500k.json",
                               "/tmp/gz_2010_us_040_00_500k.json") 
us_states = geopandas.read_file(fid[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# make a map of sampling locations

plt.rcParams.update({'font.size': 16})

ax = us_states.boundary.plot(color='black',figsize=[7,14])

tn_gdf.plot(ax=ax, color='blue',marker='.')
gdf.plot(ax=ax, color='red')

minx, miny, maxx, maxy = gdf.total_bounds
ax.set_xlim(minx-1, maxx+1)
ax.set_ylim(miny-1, maxy+1)
ax.set_title('CMC sampling locations with TN (blue) & Air Temp (red) \n N=226')

plt.show()

# %% [markdown]
# ### Plot sampling times

# %%
plt.rcParams.update({'font.size': 14})
plt.plot(at_datetime,atdf.airtemp.astype(float),'.')
plt.xlabel('Date')
plt.ylabel('Air Temperature')
plt.show()

# %% [markdown]
# ### 2. Download data from NARR FTP

# %%
# get lats & lons for NARR dataset
# pick any year, any one of the files you'll be using later 
i=2013
fid=urllib.request.urlretrieve("ftp://ftp.cdc.noaa.gov/Datasets/NARR/monolevel/air.2m."+str(i)+".nc","/tmp/air.2m."+str(i)+".nc") 
nc_fid = Dataset(fid[0],'r')
narrlats = nc_fid.variables['lat'][:].data  
narrlons = nc_fid.variables['lon'][:].data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Define a function to extract our region of interest from the NARR data

# %%
#Define a function to extract just the Chesapeake Bay region 

def extractCB(vardata,latdata,londata,latrange,lonrange):
  latlon_inds=np.where((latdata>latrange[0]) & (latdata<latrange[1])
                       & (londata>lonrange[0]) & (londata<lonrange[1]))
  var_subset=vardata[:,latlon_inds[0].min():latlon_inds[0].max(),latlon_inds[1].min():latlon_inds[1].max()]
  lat_subset=latdata[latlon_inds[0].min():latlon_inds[0].max(),latlon_inds[1].min():latlon_inds[1].max()]
  lon_subset=londata[latlon_inds[0].min():latlon_inds[0].max(),latlon_inds[1].min():latlon_inds[1].max()]
  return lat_subset, lon_subset, var_subset
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Define a function to loop through and return the subsetted area at the times of interest

# %%
# Define a function to loop through and return the subsetted area at the times of interest

def narr_subset_variable(file_prefix,varname,start_year,end_year,narr_lats,narr_lons,latrange,lonrange): 
  for i in range(start_year,end_year+1):
    fid=urllib.request.urlretrieve("ftp://ftp.cdc.noaa.gov/Datasets/NARR/monolevel/"+file_prefix+str(i)+".nc",
                                   "/tmp/"+file_prefix+str(i)+".nc") 
    nc_fid = Dataset(fid[0])
    if i==start_year:
      time = nc_fid.variables['time'][:].data
      subset_time = [dt.datetime(1800,1,1) + dt.timedelta(hours=t) for t in time]
      vartmp = nc_fid.variables[varname][:]  # shape is time, lat, lon as shown above
      latsubset, lonsubset, varsubset=extractCB(vartmp.data,narr_lats,narr_lons,latrange,lonrange)
      print(i,varname,'data imported')
    else:
      time = nc_fid.variables['time'][:].data
      dt_tmp = [dt.datetime(1800,1,1) + dt.timedelta(hours=t) for t in time]
      subset_time = np.append(subset_time,dt_tmp)
      vartmp = nc_fid.variables[varname][:]  # shape is time, lat, lon as shown above
      _, _, varsubsettmp=extractCB(vartmp.data,narr_lats,narr_lons,latrange,lonrange)
      varsubset=np.vstack((varsubset,varsubsettmp))
      print(i,varname,'data imported')
  return varsubset, subset_time, latsubset, lonsubset
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# specify inputs and run the subset function for air temperature
file_prefix='air.2m.'
varname='air'
airsubset, time_narr_import, lat_subset, lon_subset=narr_subset_variable(
  file_prefix,varname,start_year,end_year,narrlats,narrlons,latrange,lonrange)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2013 air data imported
# 2014 air data imported
# 2015 air data imported
# 2016 air data imported
# 2017 air data imported
# 2018 air data imported
# 2019 air data imported
# </div>

# %% [markdown]
# ### Plot an array with shapefile and discrete points

# %%
ax = us_states.boundary.plot(color='black',figsize=[7,14])

minx, miny, maxx, maxy = gdf.total_bounds
ax.set_xlim(minx-1, maxx+1)
ax.set_ylim(miny-1, maxy+1)

ax.pcolor(lon_subset, lat_subset, airsubset[1,:,:])
tn_gdf.plot(ax=ax, color='blue',marker='.')
gdf.plot(ax=ax, color='red')

# %% [markdown]
# ### 3. Compare the NARR data to the sampling location data

# %%
# find the time indices in the NARR timeseries corresponding to CMC and CBP measurements

# make a dataframe and make the narr timestamps the index
narrtdf=pd.DataFrame({'Datetime':pd.DatetimeIndex(time_narr_import)})
narrtdf=narrtdf.set_index('Datetime')

# make a new empty array for the time indices
narr_tind=np.array([],dtype=int) 

for i in range(len(at_datetime)):
  ttmp=at_datetime.iloc[i,1]
  #if CMC/CBP data are newer than the last timestamp for NARR data
  if (ttmp>narrtdf.index[-1]): 
    tmpind=-1
  else:
    tmpind=narrtdf.index.get_loc(ttmp,method='bfill')
  narr_tind=np.append(narr_tind,tmpind)
  
# save narr_tind as integer 
narr_tind=narr_tind.astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# first, combine the CMC coordinates and zip location data

#CMC coordinates 
allcoord = list(zip(atdf.Latitude,atdf.Longitude))

#NARR coordinates 
narrcoord = list(zip(np.ravel(lat_subset), np.ravel(lon_subset)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
narrcoord[:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[192]: [(37.61985, -81.82977),
#  (37.52493, -81.48993),
#  (37.42883, -81.15118),
#  (37.33154, -80.81352),
#  (37.23308, -80.47698),
#  (37.13345, -80.14156),
#  (37.03266, -79.80726),
#  (36.93072, -79.4741),
#  (36.82763, -79.14207),
#  (36.72341, -78.81119)]</div>

# %%
# then, find the closest NARR grid cell to the CMC coordinates 

# make a kdtree for the narr coordinates, then query it for the CMC coordinates
tree = spatial.KDTree(narrcoord)

# query and obtain corresponding climate data
narrxyid=tree.query(allcoord,k=1)

#get the matrix indices for the re-rolled matrix to correspond to the airtemp data
narrxy_ind1=(np.floor(narrxyid[1]/lat_subset.shape[1])).astype(int)
narrxy_ind2=(narrxyid[1]-narrxy_ind1*lat_subset.shape[1]).astype(int)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# extract air temp and convert kelvin to celsius
narr_cmc_airtemp=airsubset[narr_tind,narrxy_ind1,narrxy_ind2]-273.15
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
x=atdf.airtemp.astype(float)
y=narr_cmc_airtemp.astype(float)

plt.xlim(-5, 35)
plt.ylim(-5, 35)
plt.plot(x, y,'o',color = 'k')
ax.set_aspect('auto')

plt.title('CMC and NARR air temp comparison')
plt.xlabel('CMC air temp')
plt.ylabel('NARR air temp')

plt.show()
